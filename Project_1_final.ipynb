# %% [markdown]
# <a href="https://colab.research.google.com/github/brayla-oya/Cohort-18-Projects/blob/main/Project_1_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Definition
# Write a concise problem definition for the project. Put it in a text field at the top of your Jupyter notebook.
#
# This project predicts whether a future customer will make a transaction based on the anonymized data. Binary classification because the target is either 0 or 1. A successful transaction is represented as 1 & no transcation is represented as 0.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets, metrics, model_selection
from sklearn import model_selection
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

base_path = "https://ddc-datascience.s3.amazonaws.com/Projects/Project.1-Transactions/Data/"
train_path = base_path + 'Transaction.train.big.csv'
test_path = base_path + 'Transaction.test.big.csv'

# %%
train_path
# Out:
# 'https://ddc-datascience.s3.amazonaws.com/Projects/Project.1-Transactions/Data/Transaction.train.big.csv'

# %%
test_path
# Out:
# 'https://ddc-datascience.s3.amazonaws.com/Projects/Project.1-Transactions/Data/Transaction.test.big.csv'

# %% [markdown]
# ## Data Collection

# %%
# Look at first 5 rows
train_orig = pd.read_csv(train_path)
train_orig.head()
# Out:
#    Unnamed: 0  ID_code  target   var_0    var_1    var_2  var_3   var_4  \
# 0           0  train_0     NaN     NaN      NaN      NaN    NaN     NaN
# 1           1  train_1     NaN     NaN      NaN      NaN    NaN     NaN
# 2           2  train_2     NaN     NaN      NaN      NaN    NaN     NaN
# 3           3  train_3     0.0  4.6739  22.3915  15.6015    NaN  0.0464
# 4           4  train_4     NaN     NaN      NaN      NaN    NaN     NaN
#
#    var_5  var_6  ...  var_91   var_92  var_93   var_94  var_95  var_96  \
# 0    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN
# 1    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN
# 2    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN
# 3    NaN    NaN  ...     NaN  11.1077     NaN -12.6465     NaN     NaN
# 4    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN
#
#    var_97  var_98  var_99  var_100
# 0     NaN     NaN     NaN      NaN
# 1     NaN     NaN     NaN      NaN
# 2     NaN     NaN     NaN      NaN
# 3     NaN     NaN     NaN  14.0618
# 4     NaN     NaN     NaN      NaN
#
# [5 rows x 104 columns]

# %%
# Look at last 5 rows
train_orig.tail()
# Out:
#          Unnamed: 0        ID_code  target    var_0    var_1    var_2  var_3  \
# 1049995     1049995  train_1049995     1.0  11.3251  16.4148  20.5955    NaN
# 1049996     1049996  train_1049996     NaN      NaN      NaN      NaN    NaN
# 1049997     1049997  train_1049997     0.0   8.9941  13.4127   3.9567    NaN
# 1049998     1049998  train_1049998     NaN      NaN      NaN      NaN    NaN
# 1049999     1049999  train_1049999     0.0   2.1828  12.3805  17.5654    NaN
#
#           var_4  var_5  var_6  ...  var_91   var_92  var_93   var_94  var_95  \
# 1049995 -6.3011    NaN    NaN  ...     NaN   1.3921     NaN -16.4925     NaN
# 1049996     NaN    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN
# 1049997  3.5744    NaN    NaN  ...     NaN   2.0836     NaN -18.6168     NaN
# 1049998     NaN    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN
# 1049999  8.1795    NaN    NaN  ...     NaN -12.1108     NaN  10.7608     NaN
#
#          var_96  var_97  var_98  var_99  var_100
# 1049995     NaN     NaN     NaN     NaN  14.4421
# 1049996     NaN     NaN     NaN     NaN      NaN
# 1049997     NaN     NaN     NaN     NaN  14.0689
# 1049998     NaN     NaN     NaN     NaN      NaN
# 1049999     NaN     NaN     NaN     NaN  14.1690
#
# [5 rows x 104 columns]

# %%
train_orig.shape
# Out:
# (1050000, 104)

# %% [markdown]
# Data successfully loaded.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
#  First, we will create a copy of our data so that if we delete the wrong information, we can revert to this copy and start over.

# %%
# make a copy
train = train_orig.copy()
train.head()
# Out:
#    Unnamed: 0  ID_code  target   var_0    var_1    var_2  var_3   var_4  \
# 0           0  train_0     NaN     NaN      NaN      NaN    NaN     NaN
# 1           1  train_1     NaN     NaN      NaN      NaN    NaN     NaN
# 2           2  train_2     NaN     NaN      NaN      NaN    NaN     NaN
# 3           3  train_3     0.0  4.6739  22.3915  15.6015    NaN  0.0464
# 4           4  train_4     NaN     NaN      NaN      NaN    NaN     NaN
#
#    var_5  var_6  ...  var_91   var_92  var_93   var_94  var_95  var_96  \
# 0    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN
# 1    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN
# 2    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN
# 3    NaN    NaN  ...     NaN  11.1077     NaN -12.6465     NaN     NaN
# 4    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN
#
#    var_97  var_98  var_99  var_100
# 0     NaN     NaN     NaN      NaN
# 1     NaN     NaN     NaN      NaN
# 2     NaN     NaN     NaN      NaN
# 3     NaN     NaN     NaN  14.0618
# 4     NaN     NaN     NaN      NaN
#
# [5 rows x 104 columns]

# %%
# count of every unique value in the 'target' column including any missing (NaN) values.
train['target'].value_counts(dropna=False)
# Out:
# target
# NaN    870000
# 0.0    161960
# 1.0     18040
# Name: count, dtype: int64

# %%
# check all of the NaN values
train.isnull().sum().sum()
# Out:
# np.int64(97920000)

# %%
# check all of the valid values
train.notna().sum().sum()
# Out:
# np.int64(11280000)

# %%
train.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050000 entries, 0 to 1049999
# Data columns (total 104 columns):
#  #    Column      Dtype
# ---   ------      -----
#  0    Unnamed: 0  int64
#  1    ID_code     object
#  2    target      float64
#  3    var_0       float64
#  4    var_1       float64
#  5    var_2       float64
#  6    var_3       float64
#  7    var_4       float64
#  8    var_5       float64
#  9    var_6       float64
#  10   var_7       float64
#  11   var_8       float64
#  12   var_9       float64
#  13   var_10      float64
#  14   var_11      float64
#  15   var_12      float64
#  16   var_13      float64
#  17   var_14      float64
#  18   var_15      float64
#  19   var_16      float64
#  20   var_17      float64
#  21   var_18      float64
#  22   var_19      float64
#  23   var_20      float64
#  24   var_21      float64
#  25   var_22      float64
#  26   var_23      float64
#  27   var_24      float64
#  28   var_25      float64
#  29   var_26      float64
#  30   var_27      float64
#  31   var_28      float64
#  32   var_29      float64
#  33   var_30      float64
#  34   var_31      float64
#  35   var_32      float64
#  36   var_33      float64
#  37   var_34      float64
#  38   var_35      float64
#  39   var_36      float64
#  40   var_37      float64
#  41   var_38      float64
#  42   var_39      float64
#  43   var_40      float64
#  44   var_41      float64
#  45   var_42      float64
#  46   var_43      float64
#  47   var_44      float64
#  48   var_45      float64
#  49   var_46      float64
#  50   var_47      float64
#  51   var_48      float64
#  52   var_49      float64
#  53   var_50      float64
#  54   var_51      float64
#  55   var_52      float64
#  56   var_53      float64
#  57   var_54      float64
#  58   var_55      float64
#  59   var_56      float64
#  60   var_57      float64
#  61   var_58      float64
#  62   var_59      float64
#  63   var_60      float64
#  64   var_61      float64
#  65   var_62      float64
#  66   var_63      float64
#  67   var_64      float64
#  68   var_65      float64
#  69   var_66      float64
#  70   var_67      float64
#  71   var_68      float64
#  72   var_69      float64
#  73   var_70      float64
#  74   var_71      float64
#  75   var_72      float64
#  76   var_73      float64
#  77   var_74      float64
#  78   var_75      float64
#  79   var_76      float64
#  80   var_77      float64
#  81   var_78      float64
#  82   var_79      float64
#  83   var_80      float64
#  84   var_81      float64
#  85   var_82      float64
#  86   var_83      float64
#  87   var_84      float64
#  88   var_85      float64
#  89   var_86      float64
#  90   var_87      float64
#  91   var_88      float64
#  92   var_89      float64
#  93   var_90      float64
#  94   var_91      float64
#  95   var_92      float64
#  96   var_93      float64
#  97   var_94      float64
#  98   var_95      float64
#  99   var_96      float64
#  100  var_97      float64
#  101  var_98      float64
#  102  var_99      float64
#  103  var_100     float64
# dtypes: float64(102), int64(1), object(1)
# memory usage: 833.1+ MB

# %% [markdown]
# We can drop the "ID_code" & "Unnamed: 0" columns because they are just placeholders and won't affect the data if they are deleted.

# %%
# columns (axis=1) dropped and changes are applied directly to the train
train.drop('ID_code', axis=1 , inplace=True)
train.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# new set of data with the two columns removed
train.head()
# Out:
#    target   var_0    var_1    var_2  var_3   var_4  var_5  var_6   var_7  \
# 0     NaN     NaN      NaN      NaN    NaN     NaN    NaN    NaN     NaN
# 1     NaN     NaN      NaN      NaN    NaN     NaN    NaN    NaN     NaN
# 2     NaN     NaN      NaN      NaN    NaN     NaN    NaN    NaN     NaN
# 3     0.0  4.6739  22.3915  15.6015    NaN  0.0464    NaN    NaN -1.9254
# 4     NaN     NaN      NaN      NaN    NaN     NaN    NaN    NaN     NaN
#
#    var_8  ...  var_91   var_92  var_93   var_94  var_95  var_96  var_97  \
# 0    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN     NaN
# 1    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN     NaN
# 2    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN     NaN
# 3  6.476  ...     NaN  11.1077     NaN -12.6465     NaN     NaN     NaN
# 4    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN     NaN
#
#    var_98  var_99  var_100
# 0     NaN     NaN      NaN
# 1     NaN     NaN      NaN
# 2     NaN     NaN      NaN
# 3     NaN     NaN  14.0618
# 4     NaN     NaN      NaN
#
# [5 rows x 102 columns]

# %% [markdown]
# We still have some columns with nulls that need to be removed.

# %%
# less than 1 non-null value
train.dropna(thresh=1,axis=1,inplace=True)
train.head()
# Out:
#    target   var_0    var_1    var_2   var_4   var_7  var_8   var_14  var_15  \
# 0     NaN     NaN      NaN      NaN     NaN     NaN    NaN      NaN     NaN
# 1     NaN     NaN      NaN      NaN     NaN     NaN    NaN      NaN     NaN
# 2     NaN     NaN      NaN      NaN     NaN     NaN    NaN      NaN     NaN
# 3     0.0  4.6739  22.3915  15.6015  0.0464 -1.9254  6.476  21.6435  2.8817
# 4     NaN     NaN      NaN      NaN     NaN     NaN    NaN      NaN     NaN
#
#     var_17  ...   var_83  var_84  var_85  var_86  var_87  var_88  var_89  \
# 0      NaN  ...      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1      NaN  ...      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2      NaN  ...      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3  11.6975  ...  11.8011  3.9677  9.5382 -8.4394  5.5043  2.2732  1.6362
# 4      NaN  ...      NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#     var_92   var_94  var_100
# 0      NaN      NaN      NaN
# 1      NaN      NaN      NaN
# 2      NaN      NaN      NaN
# 3  11.1077 -12.6465  14.0618
# 4      NaN      NaN      NaN
#
# [5 rows x 51 columns]

# %% [markdown]
# Now that the necessary columns are removed, we can see that there are still some NaNs in the rows. Those can be removed now.

# %%
train.dropna(thresh=1,axis=0,inplace=True)
train.head()
# Out:
#     target    var_0    var_1    var_2   var_4   var_7   var_8   var_14  \
# 3      0.0   4.6739  22.3915  15.6015  0.0464 -1.9254  6.4760  21.6435
# 5      0.0  14.6962  18.3383  17.4788 -9.1355 -6.4882  6.0821  11.7476
# 11     0.0   4.4949  14.4142  13.2219  4.9140  4.0501  5.8144  18.7136
# 15     0.0   4.9657  16.2867  17.9579  0.6017 -5.4904  6.6670   8.1019
# 19     0.0   9.4287  18.7822  10.7630 -0.7532  8.8477  6.8045  19.0069
#
#     var_15   var_17  ...   var_83  var_84  var_85   var_86   var_87  var_88  \
# 3   2.8817  11.6975  ...  11.8011  3.9677  9.5382  -8.4394   5.5043  2.2732
# 5   2.2225   7.2218  ...  11.8294  3.8887  8.8591   6.1482   8.5833  2.8432
# 11  3.4990   4.2892  ...  11.7464  4.0017  5.8179  10.4951  12.4494  2.8009
# 15  2.8910   8.2374  ...  11.5481  3.9809  8.2247  21.2257   6.9931  3.3939
# 19  3.2771  12.6446  ...  10.8981  4.1808  9.4220   1.8563  10.5738  1.2409
#
#     var_89   var_92   var_94  var_100
# 3   1.6362  11.1077 -12.6465  14.0618
# 5   1.8434  -2.0111  -3.6166  14.4520
# 11  0.3394  13.9424 -15.5776  14.1222
# 15 -2.3905   3.7943   5.6184  14.0619
# 19 -1.3888  -5.6677  -1.8961  14.0275
#
# [5 rows x 51 columns]

# %% [markdown]
# Now we need to make sure all nulls are gone before proceeding further.

# %%
# checking to make sure all nulls are gone
train.transpose().isnull().sum().sum()
# Out:
# np.int64(0)

# %%
train_test = train.copy()

# %%
# Checking to make sure we have zeros & ones.
train_test['target'].value_counts(dropna=False)
# Out:
# target
# 0.0    161960
# 1.0     18040
# Name: count, dtype: int64

# %%
train_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 180000 entries, 3 to 1049999
# Data columns (total 51 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   target   180000 non-null  float64
#  1   var_0    180000 non-null  float64
#  2   var_1    180000 non-null  float64
#  3   var_2    180000 non-null  float64
#  4   var_4    180000 non-null  float64
#  5   var_7    180000 non-null  float64
#  6   var_8    180000 non-null  float64
#  7   var_14   180000 non-null  float64
#  8   var_15   180000 non-null  float64
#  9   var_17   180000 non-null  float64
#  10  var_20   180000 non-null  float64
#  11  var_21   180000 non-null  float64
#  12  var_22   180000 non-null  float64
#  13  var_24   180000 non-null  float64
#  14  var_26   180000 non-null  float64
#  15  var_27   180000 non-null  float64
#  16  var_28   180000 non-null  float64
#  17  var_29   180000 non-null  float64
#  18  var_36   180000 non-null  float64
#  19  var_37   180000 non-null  float64
#  20  var_38   180000 non-null  float64
#  21  var_39   180000 non-null  float64
#  22  var_41   180000 non-null  float64
#  23  var_48   180000 non-null  float64
#  24  var_49   180000 non-null  float64
#  25  var_52   180000 non-null  float64
#  26  var_56   180000 non-null  float64
#  27  var_57   180000 non-null  float64
#  28  var_61   180000 non-null  float64
#  29  var_62   180000 non-null  float64
#  30  var_63   180000 non-null  float64
#  31  var_65   180000 non-null  float64
#  32  var_66   180000 non-null  float64
#  33  var_67   180000 non-null  float64
#  34  var_70   180000 non-null  float64
#  35  var_72   180000 non-null  float64
#  36  var_73   180000 non-null  float64
#  37  var_75   180000 non-null  float64
#  38  var_78   180000 non-null  float64
#  39  var_80   180000 non-null  float64
#  40  var_82   180000 non-null  float64
#  41  var_83   180000 non-null  float64
#  42  var_84   180000 non-null  float64
#  43  var_85   180000 non-null  float64
#  44  var_86   180000 non-null  float64
#  45  var_87   180000 non-null  float64
#  46  var_88   180000 non-null  float64
#  47  var_89   180000 non-null  float64
#  48  var_92   180000 non-null  float64
#  49  var_94   180000 non-null  float64
#  50  var_100  180000 non-null  float64
# dtypes: float64(51)
# memory usage: 71.4 MB

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Everything in the target column is now a zero or a one, which is what we want. We can see that there are a lot more zeroes than ones. This means our data is skewed.

# %%
for column in train_test.columns:
  sns.displot(train_test, x=column, kde=False, discrete=False)
  plt.show()

# %%
for column in train_test.columns:
    plt.figure(figsize=(5,3))
    sns.histplot(train_test[column], bins=30,)
    plt.show()

# %%
train_test.hist(figsize=(22,22)) ;

# %%
corr_matrix = train_test.corr()

# %%
corr_matrix = train_test.corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, cmap="spring", square=True, linewidths=0.1, vmin=-1, vmax=1) ;
plt.savefig('correlation matrix.png')

# %% [markdown]
# No correlation.
#
# This paired with the normal distribution histograms of values shows that the Gaussian Naive Bayes model will work.

# %%
filter1 = ( train_test["target"] == 1)
train_filter1 = train_test[filter1]
filter0 = ( train_test["target"] == 0)
train_filter0 = train_test[filter0]

# %%
train_filter1.shape
# Out:
# (18040, 51)

# %%
train_filter0.shape
# Out:
# (161960, 51)

# %% [markdown]
# ## Data Processing
#
# -We are now separating the target & the vars.

# %%
train_target = train_test['target']
train_target
# Out:
# 3          0.0
# 5          0.0
# 11         0.0
# 15         0.0
# 19         0.0
#           ...
# 1049990    0.0
# 1049993    0.0
# 1049995    1.0
# 1049997    0.0
# 1049999    0.0
# Name: target, Length: 180000, dtype: float64

# %%
train_vars = train_test.drop('target',axis=1)
train_vars
# Out:
#            var_0    var_1    var_2   var_4   var_7   var_8   var_14  var_15  \
# 3         4.6739  22.3915  15.6015  0.0464 -1.9254  6.4760  21.6435  2.8817
# 5        14.6962  18.3383  17.4788 -9.1355 -6.4882  6.0821  11.7476  2.2225
# 11        4.4949  14.4142  13.2219  4.9140  4.0501  5.8144  18.7136  3.4990
# 15        4.9657  16.2867  17.9579  0.6017 -5.4904  6.6670   8.1019  2.8910
# 19        9.4287  18.7822  10.7630 -0.7532  8.8477  6.8045  19.0069  3.2771
# ...          ...      ...      ...     ...     ...     ...      ...     ...
# 1049990   7.9632  20.4650  10.7295  2.9322  5.0267  7.1953  10.0695  3.0732
# 1049993   5.0862  14.4785  17.3709 -2.4732 -2.5987  6.6798   3.0420  2.4057
# 1049995  11.3251  16.4148  20.5955 -6.3011 -6.8112  7.3226  14.9182  2.4579
# 1049997   8.9941  13.4127   3.9567  3.5744  1.6614  6.1486  12.0996  2.5439
# 1049999   2.1828  12.3805  17.5654  8.1795 -5.5755  6.3705   5.1813  2.5118
#
#           var_17   var_20  ...   var_83  var_84  var_85   var_86   var_87  \
# 3        11.6975   0.5878  ...  11.8011  3.9677  9.5382  -8.4394   5.5043
# 5         7.2218   6.5456  ...  11.8294  3.8887  8.8591   6.1482   8.5833
# 11        4.2892  18.7893  ...  11.7464  4.0017  5.8179  10.4951  12.4494
# 15        8.2374   1.1400  ...  11.5481  3.9809  8.2247  21.2257   6.9931
# 19       12.6446   7.8002  ...  10.8981  4.1808  9.4220   1.8563  10.5738
# ...          ...      ...  ...      ...     ...     ...      ...      ...
# 1049990  11.0135   3.1549  ...  12.1000  4.2019  7.1249  14.6591  10.2705
# 1049993  18.2729   3.9661  ...  10.9960  3.9637  8.0217  11.0449   9.3100
# 1049995  14.7175   3.8858  ...  11.2265  3.8431  8.2748  -7.8464   9.9774
# 1049997  10.2936   2.0014  ...  10.5067  4.0642  8.3381  17.9081  12.3357
# 1049999  10.0141 -14.7574  ...  12.0632  3.8415  6.3466  30.6304  10.7439
#
#          var_88  var_89   var_92   var_94  var_100
# 3        2.2732  1.6362  11.1077 -12.6465  14.0618
# 5        2.8432  1.8434  -2.0111  -3.6166  14.4520
# 11       2.8009  0.3394  13.9424 -15.5776  14.1222
# 15       3.3939 -2.3905   3.7943   5.6184  14.0619
# 19       1.2409 -1.3888  -5.6677  -1.8961  14.0275
# ...         ...     ...      ...      ...      ...
# 1049990  3.5833  2.5588  10.4219 -19.7158  14.0582
# 1049993  1.0545 -2.8770  -2.8052 -13.7290  14.3794
# 1049995  1.7377 -1.7942   1.3921 -16.4925  14.4421
# 1049997  2.6530 -1.2359   2.0836 -18.6168  14.0689
# 1049999 -0.1808  0.2578 -12.1108  10.7608  14.1690
#
# [180000 rows x 50 columns]

# %%
gnb = GaussianNB()

# %%
# target = y
y = train['target'].copy()
# # vars = x
x = train.drop('target', axis=1, inplace=False)

# %% [markdown]
# I think I made this a little more difficult than it needed to be.
# I could have used "x_train, x_test, y_train, & y_test" since I set them to
# x & y previously.

# %%
# train_test_split = splits data into train/test sets
# gnb.fit = trains the model
# gnb.predict = predicts test data labels
# vars_test != vars_pred = finds the incorrect predictions
vars_train, vars_test, target_train, target_test = train_test_split(train_vars, train_target, test_size = 0.20, random_state = 44)
gnb.fit(vars_train, target_train)
target_pred = gnb.predict(vars_test)
print("Number of mislabeled points out of a total %d points : %d"
      % (vars_test.shape[0], (target_test != target_pred).sum()))
# Out:
# Number of mislabeled points out of a total 36000 points : 3209

# %%
# checks that all are dfs or series
for i in [vars_train, vars_test, target_train, target_test ]:
  print(type(i))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
for i in [vars_train, vars_test, target_train, target_test ]:
  print(i.shape)
# Out:
# (144000, 50)
# (36000, 50)
# (144000,)
# (36000,)

# %%
# this shows when the prediction is correct (0) &
# when prediction is wrong (+/-1000)
(target_test.to_numpy() - vars_pred)*1000
# Out:
# array([1000.,    0., 1000., ...,    0.,    0.,    0.])

# %%
# calculates accuracy
(1-3209/36000) *100
# Out:
# 91.08611111111111

# %% [markdown]
# ### Cross-Validation
# A cross-validation will be performed to see the average accuracy.
#
# -Creates empty numpy array of zeros. This is filled w/ accuracy values from each loop
#
# -num_loops is the number of times the model runs
#
# -a new GNB model is ran fresh each time
#
# -data is split 80/20 w/ 20 being for testing
#
# -trains model on training data
#
# -computes accuracy for the round
#
# -then it returns the full array of accuracy scores

# %%
def cross_validate(x, y, num_loops):

  accuracy_scores = np.zeros(num_loops)

# num_loops is the number of times the model runs
  for i in range(num_loops):
    model_split_cv = GaussianNB()
    x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, test_size = 0.2)
    model_split_cv.fit(x_train, y_train)
    y_split_pred = model_split_cv.predict(x_test)
    accuracy_scores[i] = metrics.accuracy_score(y_test, y_split_pred)

  return accuracy_scores

# %%
# 100 samples ran through
accuracy_scores = cross_validate(x, y, 100)
print(round(accuracy_scores.mean(), 5))
# Out:
# 0.91129

# %% [markdown]
# Over 100 random splits, my GNB model predicted the target correctly 91.129% of the time on average.

# %%
# 17
metrics.ConfusionMatrixDisplay.from_estimator(
    gnb,
    vars_test,
    target_test,
    normalize = 'true',
    values_format = '.2%',
    cmap = 'summer',
    )
plt.grid(False)
plt.title('Confusion matrix') ;
plt.savefig('confusion_matrix.png')

# %% [markdown]
# The confusion matrix shows that most of the data leans towards transactions that didn’t go through successfully. It also shows that it is weak and detecting successful transactions. This is common problem in imbalanced sets.

# %%
plt.hist(accuracy_scores, bins=10, color='aquamarine', edgecolor='teal') ;
plt.title('Accuracy Scores Generated (100 runs)') ;
plt.xlabel('Accuracy') ;
plt.ylabel('Frequency') ;
plt.show() ;
plt.savefig('Accuracy Scores Genterated.png') ;

# %% [markdown]
# ### 50/50 Cross Validation

# %%
success = train_test.drop('target',axis=1).copy()
fail = train['target'].copy()

# %%
# make fail equal to success for 50/50 (downsample)
# n=len(success) - picks exact number of rows in the success set
failed_downsampled = fail.sample(n=len(success), random_state=44)

# %%
# combining success & fail dfs
# .sample(frac=1) means shuffle 100% of rows
train_balanced = pd.concat([success, failed_downsampled]).sample(frac=1, random_state=44)

# %%
x_balanced = train_balanced.drop('target', axis=1)
y_balanced = train_balanced['target']

# %%
# 100 samples ran through
accuracy_scores = cross_validate(x, y, 100)
print(round(accuracy_scores.mean(), 5))
# Out:
# 0.91133

# %% [markdown]
# This is where I'm confused. I feel like the 50/50 data would be a lower % than the full data.

# %%
metrics.ConfusionMatrixDisplay.from_estimator(
    gnb,
    success,
    fail,
    normalize = 'true',
    values_format = '.2%',
    cmap = 'autumn',
    )
plt.grid(False)
plt.title('50/50 Confusion matrix') ;

# %%
plt.hist(accuracy_scores, bins=10, color='gold', edgecolor='brown') ;
plt.title('50/50 Accuracy Scores Generated (100 runs)') ;
plt.xlabel('Accuracy') ;
plt.ylabel('Frequency') ;
plt.show() ;

# %% [markdown]
# ## Data Visualization

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(target_test, target_pred))
print(classification_report(target_test, target_pred))
# Out:
# [[31986   458]
#  [ 2751   805]]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.99      0.95     32444
#          1.0       0.64      0.23      0.33      3556
#
#     accuracy                           0.91     36000
#    macro avg       0.78      0.61      0.64     36000
# weighted avg       0.89      0.91      0.89     36000

# %% [markdown]
# ## Communicate the Results

# %% [markdown]
# Summary: Executed a Gaussian Naive Bayes classifier, highlighting the need for data cleaning, EDA, cross-validation, and handling class imbalance for strong model performance.
#
# Both cross-validation & 50/50 validation gave an accuracy of 91%. I know that the 50/50 should be lower. Balancing the datasets will often lead to a balanced trade-off. It will also improve the model's perfomance.
#
# Strengths: Gaussian Naive Bayes is efficient and effective with independent, normally distributed features.
#
# Future Enhancements:
# - Explore other classifiers (Logistic Regression, Random Forest, Gradient Boosting).
# - Advance feature engineering.
# - Investigate missing data imputation strategies.
# - Consider alternate sampling techniques for imbalance
